# %% [markdown]
# GDSC TASK 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Varni\Downloads\country_wise_latest.csv")
df
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
#inserting colums in databse
avg_age=np.linspace(1,98,187)
df['averag age']=avg_age
df
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
#making new column based on existing columns
df['Total deaths']=df['Deaths']+df['New deaths']
df
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
Deaths=df['Deaths']
Country=df['Country/Region']
ax.bar(Country,Deaths)
plt.show()

# %%
fig1=plt.figure()
ax=fig1.add_axes([0,0,1,1])
ax.pie(Deaths, labels=Country,autopct='%1.1f%%')
plt.show()

# %%
#rename columns
df.rename(columns={'WHO Region':'WHO'})
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
#extracting specific part of data
df.loc[:,'Active':'WHO Region']
# Out:
#      Active  New cases  New deaths  New recovered  Deaths / 100 Cases  \
# 0      9796        106          10             18                3.50
# 1      1991        117           6             63                2.95
# 2      7973        616           8            749                4.16
# 3        52         10           0              0                5.73
# 4       667         18           1              0                4.32
# ..      ...        ...         ...            ...                 ...
# 182    6791        152           2              0                0.73
# 183       1          0           0              0               10.00
# 184     375         10           4             36               28.56
# 185    1597         71           1            465                3.08
# 186    2126        192           2             24                1.33
#
#      Recovered / 100 Cases  Deaths / 100 Recovered  Confirmed last week  \
# ...

# %%
#access a single cell
df.iat[1,1]
# Out:
# 4880

# %%
#filtering rows as per conditions
a=df['New deaths']>5
a
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# Name: New deaths, Length: 187, dtype: bool

# %%
#sorting
df.sort_values(by='New cases', ascending=False)
# Out:
#         Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 173                 US    4290259  148011    1325804  2816444      56336
# 79               India    1480073   33408     951166   495499      44457
# 23              Brazil    2442375   87618    1846641   508116      23284
# 37            Colombia     257101    8777     131161   117163      16306
# 132               Peru     389717   18418     272547    98752      13756
# ..                 ...        ...     ...        ...      ...        ...
# 157              Spain     272421   28432     150376    93613          0
# 54   Equatorial Guinea       3071      51        842     2178          0
# 100      Liechtenstein         86       1         81        4          0
# 95              Latvia       1219      31       1045      143          0
# 56             Estonia       2034      69       1923       42          0
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...
